# %%
import pandas as pd
import os
import warnings

warnings.filterwarnings("ignore")

# %%
folder_path = 'csv_panama_papers'

# %%
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# %%
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)

    
    df_name = csv_file.split('.')[2] if len(csv_file.split('.')) > 2 else None
    globals()[df_name] = pd.read_csv(file_path)
    print(df_name)
# Out:
# address
# entity
# intermediary
# csv
# officer

# %%
edges = csv.copy()

# %%
print(f"Shape of Officers = {officer.shape}")
print(f"Shape of Interediary = {intermediary.shape}")
print(f"Shape of Adresses = {address.shape}")
print("Shape of Edges start = ", edges["START_ID"].nunique())
print("Shape of Edges end = ", edges["END_ID"].nunique())
# Out:
# Shape of Officers = (238402, 7)
# Shape of Interediary = (14110, 8)
# Shape of Adresses = (93454, 8)
# Shape of Edges start =  257667
# Shape of Edges end =  307082

# %% [markdown]
# ## DRAFT

# %%
edges.loc[edges['TYPE'] == 'officer_of']['link'].value_counts().head(10)
# Out:
# shareholder of                              293961
# beneficiary of                               15150
# beneficial owner of                             79
# director of                                     48
# power of attorney of                            29
# owner, director and shareholder of              28
# owner of                                        16
# director / shareholder of                        6
# beneficiary, shareholder and director of         6
# sole shareholder of                              4
# Name: link, dtype: int64

# %%
edges.loc[edges['TYPE'] == 'intermediary_of'].head()
# Out:
#       START_ID             TYPE    END_ID             link start_date  \
# 5310  11000001  intermediary_of  10208879  intermediary of        NaN
# 5311  11000001  intermediary_of  10198662  intermediary of        NaN
# 5312  11000001  intermediary_of  10159927  intermediary of        NaN
# 5313  11000001  intermediary_of  10165779  intermediary of        NaN
# 5314  11000001  intermediary_of  10152967  intermediary of        NaN
#
#      end_date       sourceID                                     valid_until
# 5310      NaN  Panama Papers  The Panama Papers data is current through 2015
# 5311      NaN  Panama Papers  The Panama Papers data is current through 2015
# 5312      NaN  Panama Papers  The Panama Papers data is current through 2015
# 5313      NaN  Panama Papers  The Panama Papers data is current through 2015
# 5314      NaN  Panama Papers  The Panama Papers data is current through 2015

# %%
edges.loc[edges['TYPE'] == 'intermediary_of']['link'].value_counts()
# Out:
# intermediary of    213634
# Name: link, dtype: int64

# %%
registered_address

# %%
edges.loc[edges['TYPE'] == 'registered_address'].head()
# Out:
#    START_ID                TYPE    END_ID                link start_date  \
# 0  10000035  registered_address  14095990  registered address        NaN
# 1  10000044  registered_address  14091035  registered address        NaN
# 2  10000055  registered_address  14095990  registered address        NaN
# 3  10000064  registered_address  14091429  registered address        NaN
# 4  10000089  registered_address  14098253  registered address        NaN
#
#   end_date       sourceID valid_until
# 0      NaN  Panama Papers         NaN
# 1      NaN  Panama Papers         NaN
# 2      NaN  Panama Papers         NaN
# 3      NaN  Panama Papers         NaN
# 4      NaN  Panama Papers         NaN

# %%
edges.loc[edges['TYPE'] == 'registered_address']['link'].value_counts()
# Out:
# registered address    151105
# Name: link, dtype: int64

# %%
entity.head()
# Out:
#     node_id                                         name jurisdiction  \
# 0  10000001     TIANSHENG INDUSTRY AND TRADING CO., LTD.          SAM
# 1  10000002  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.          SAM
# 2  10000003                           HOTFOCUS CO., LTD.          SAM
# 3  10000004              SKY-BLUE GIFTS & TOYS CO., LTD.          SAM
# 4  10000005         FORTUNEMAKER INVESTMENTS CORPORATION          SAM
#
#   jurisdiction_description country_codes  countries incorporation_date  \
# 0                    Samoa           HKG  Hong Kong        23-MAR-2006
# 1                    Samoa           HKG  Hong Kong        27-MAR-2006
# 2                    Samoa           HKG  Hong Kong        10-JAN-2006
# 3                    Samoa           HKG  Hong Kong        06-JAN-2006
# 4                    Samoa           HKG  Hong Kong        19-APR-2006
#
#   inactivation_date struck_off_date  closed_date  ibcRUC         status  \
# ...

# %%
test = pd.merge(entity,officer, how = 'inner', on = 'node_id' )

# %%
entity.loc[entity['node_id'] == 12000005]
# Out:
# Empty DataFrame
# Columns: [node_id, name, jurisdiction, jurisdiction_description, country_codes, countries, incorporation_date, inactivation_date, struck_off_date, closed_date, ibcRUC, status, company_type, service_provider, sourceID, valid_until, note]
# Index: []

# %%
officer.head()
# Out:
#     node_id                  name country_codes    countries       sourceID  \
# 0  12000001            KIM SOO IN           KOR  South Korea  Panama Papers
# 1  12000002             Tian Yuan           CHN        China  Panama Papers
# 2  12000003  GREGORY JOHN SOLOMON           AUS    Australia  Panama Papers
# 3  12000004        MATSUDA MASUMI           JPN        Japan  Panama Papers
# 4  12000005           HO THUY NGA           VNM     Viet Nam  Panama Papers
#
#                                       valid_until note
# 0  The Panama Papers data is current through 2015  NaN
# 1  The Panama Papers data is current through 2015  NaN
# 2  The Panama Papers data is current through 2015  NaN
# 3  The Panama Papers data is current through 2015  NaN
# 4  The Panama Papers data is current through 2015  NaN

# %%
print(officer["node_id"].nunique())
print(officer.shape)
# Out:
# 238402
# (238402, 7)

# %%
print(entity["node_id"].nunique())
print(entity.shape)
# Out:
# 213634
# (213634, 17)

# %%
entity.head(5)
# Out:
#     node_id                                         name jurisdiction  \
# 0  10000001     TIANSHENG INDUSTRY AND TRADING CO., LTD.          SAM
# 1  10000002  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.          SAM
# 2  10000003                           HOTFOCUS CO., LTD.          SAM
# 3  10000004              SKY-BLUE GIFTS & TOYS CO., LTD.          SAM
# 4  10000005         FORTUNEMAKER INVESTMENTS CORPORATION          SAM
#
#   jurisdiction_description country_codes  countries incorporation_date  \
# 0                    Samoa           HKG  Hong Kong        23-MAR-2006
# 1                    Samoa           HKG  Hong Kong        27-MAR-2006
# 2                    Samoa           HKG  Hong Kong        10-JAN-2006
# 3                    Samoa           HKG  Hong Kong        06-JAN-2006
# 4                    Samoa           HKG  Hong Kong        19-APR-2006
#
#   inactivation_date struck_off_date  closed_date  ibcRUC         status  \
# ...

# %%
entity["valid_until"].value_counts()
# Out:
# valid_until
# The Panama Papers data is current through 2015    213634
# Name: count, dtype: int64

# %%
# unique of this is the roles table
roles_table = edges.loc[edges['TYPE'] == 'officer_of']['link'].unique()
sorted(roles_table)
# Out:
# ['authorized signatory of',
#  'beneficial owner of',
#  'beneficiary of',
#  'beneficiary, shareholder and director of',
#  'connected of',
#  'director (rami makhlouf) of',
#  'director / beneficial owner of',
#  'director / shareholder / beneficial owner of',
#  'director / shareholder of',
#  'director and shareholder of',
#  'director of',
#  'first beneficiary of',
#  'grantee of a mortgage of',
#  'member / shareholder of',
#  'member of foundation council of',
#  'owner of',
#  'owner, director and shareholder of',
#  'power of attorney / shareholder of',
#  'power of attorney of',
#  'president - director of',
#  'president and director of',
#  'president of',
#  'principal beneficiary of',
#  'protector of',
#  'secretary of',
#  'shareholder (through julex foundation) of',
#  'shareholder of',
#  'signatory of',
#  'sole shareholder of',
#  'sole signatory / beneficial owner of',
#  'sole signatory of']

# %%
edges.head(5)
# Out:
#    START_ID                TYPE    END_ID                link start_date  \
# 0  10000035  registered_address  14095990  registered address        NaN
# 1  10000044  registered_address  14091035  registered address        NaN
# 2  10000055  registered_address  14095990  registered address        NaN
# 3  10000064  registered_address  14091429  registered address        NaN
# 4  10000089  registered_address  14098253  registered address        NaN
#
#   end_date       sourceID valid_until
# 0      NaN  Panama Papers         NaN
# 1      NaN  Panama Papers         NaN
# 2      NaN  Panama Papers         NaN
# 3      NaN  Panama Papers         NaN
# 4      NaN  Panama Papers         NaN

# %%
test = pd.merge(officer,edges, how = 'inner', left_on = 'node_id', right_on = 'START_ID')

# %%
test.head()
# Out:
#     node_id                  name country_codes    countries     sourceID_x  \
# 0  12000001            KIM SOO IN           KOR  South Korea  Panama Papers
# 1  12000001            KIM SOO IN           KOR  South Korea  Panama Papers
# 2  12000002             Tian Yuan           CHN        China  Panama Papers
# 3  12000002             Tian Yuan           CHN        China  Panama Papers
# 4  12000003  GREGORY JOHN SOLOMON           AUS    Australia  Panama Papers
#
#                                     valid_until_x note  START_ID  \
# 0  The Panama Papers data is current through 2015  NaN  12000001
# 1  The Panama Papers data is current through 2015  NaN  12000001
# 2  The Panama Papers data is current through 2015  NaN  12000002
# 3  The Panama Papers data is current through 2015  NaN  12000002
# 4  The Panama Papers data is current through 2015  NaN  12000003
#
#                  TYPE    END_ID                link   start_date     end_date  \
# ...

# %%
entity.head()
# Out:
#    entity_id                                         name jurisdiction  \
# 0   10000001     TIANSHENG INDUSTRY AND TRADING CO., LTD.          SAM
# 1   10000002  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.          SAM
# 2   10000003                           HOTFOCUS CO., LTD.          SAM
# 3   10000004              SKY-BLUE GIFTS & TOYS CO., LTD.          SAM
# 4   10000005         FORTUNEMAKER INVESTMENTS CORPORATION          SAM
#
#   jurisdiction_description country_code country_name incorporation_date  \
# 0                    Samoa          HKG    Hong Kong        23-MAR-2006
# 1                    Samoa          HKG    Hong Kong        27-MAR-2006
# 2                    Samoa          HKG    Hong Kong        10-JAN-2006
# 3                    Samoa          HKG    Hong Kong        06-JAN-2006
# 4                    Samoa          HKG    Hong Kong        19-APR-2006
#
#   inactivation_date struck_off_date  closed_date ibc_ruc         status  \
# ...

# %% [markdown]
# ## Entities

# %%
entity["name"] = entity["name"].fillna(value = "no_name")

# %%
entity["name"].isnull().sum()
# Out:
# 4

# %%
entity.dtypes
# Out:
# entity_id                     int64
# name                         object
# jurisdiction                 object
# jurisdiction_description     object
# country_code                 object
# country_name                 object
# incorporation_date           object
# inactivation_date            object
# struck_off_date              object
# closed_date                 float64
# ibc_ruc                      object
# status                       object
# company_type                float64
# service_provider             object
# source_id                    object
# valid_until                  object
# note                         object
# dtype: object

# %%
entity.shape
# Out:
# (213634, 17)

# %%
max_lengths = {}

# Iterate over each column in the DataFrame
for column in entity.columns:
    # Calculate the maximum length for each cell in the column
    max_length_in_column = entity[column].astype(str).apply(len).max()
    
    # Store the result in the dictionary
    max_lengths[column] = max_length_in_column

# Print the maximum lengths for each column
for column, max_length in max_lengths.items():
    print(f"Maximum length in '{column}': {max_length}")
# Out:
# Maximum length in 'entity_id': 8
# Maximum length in 'name': 128
# Maximum length in 'jurisdiction': 4
# Maximum length in 'jurisdiction_description': 22
# Maximum length in 'country_code': 3
# Maximum length in 'country_name': 32
# Maximum length in 'incorporation_date': 11
# Maximum length in 'inactivation_date': 11
# Maximum length in 'struck_off_date': 11
# Maximum length in 'closed_date': 3
# Maximum length in 'ibc_ruc': 17
# Maximum length in 'status': 34
# Maximum length in 'company_type': 3
# Maximum length in 'service_provider': 15
# Maximum length in 'source_id': 13
# Maximum length in 'valid_until': 46
# Maximum length in 'note': 865

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# Assuming you have a DataFrame named 'df' and a PostgreSQL connection is established

# PostgreSQL connection parameters
db_params = {
    'host': 'localhost',
    'port': 5432,
    'user': 'postgres',
    'password': 'useruser',
    'database': 'postgres'
}

# Create a connection to the PostgreSQL database
connection = psycopg2.connect(**db_params)

# Create a SQLAlchemy engine
engine = create_engine(f'postgresql://{db_params["user"]}:{db_params["password"]}@{db_params["host"]}:{db_params["port"]}/{db_params["database"]}')

# Close the database connection
connection.close()

# %%
def data_parser(df_name, db_table_columns, db_table_name):
    try:
        column_mapping = dict(zip(df_name.columns, db_table_columns))
        df_name.rename(columns=column_mapping, inplace=True)
        df_name.to_sql(db_table_name, engine, if_exists='append', index=False)
        return print(f"Data successfully parsed to {db_table_name} table")
    except Exception as e:
        print(f"Error: {e}")
        return print(f"Data was not parsed to {db_table_name} table")

# %%
db_entity_columns = [
    'entity_id',
    'name',
    'jurisdiction',
    'jurisdiction_description',
    'country_code',
    'country_name',
    'incorporation_date',
    'inactivation_date',
    'struck_off_date',
    'closed_date',
    'ibc_ruc',
    'status',
    'company_type',
    'service_provider',
    'source_id',
    'valid_until',
    'note'
]

#column_mapping = dict(zip(entity.columns, db_table_columns))
#column_mapping

# %%
entity.rename(columns=column_mapping, inplace=True)

# %%
entity.to_sql("entities_2307_2325", engine, if_exists='append', index=False)
# Out:
# 634

# %%
data_parser(entity, db_entity_columns, "entities_2307_2325")
# Out:
# Data successfully parsed to entities_2307_2325 table

# %% [markdown]
# ## Role

# %%
roles_table = sorted(edges.loc[edges['TYPE'] == 'officer_of']['link'].unique())
roles_df = pd.DataFrame(roles_table, columns=["role_type"]).copy()

# %%
roles_df
# Out:
#     role_id                                     role_type
# 0         1                       authorized signatory of
# 1         2                           beneficial owner of
# 2         3                                beneficiary of
# 3         4      beneficiary, shareholder and director of
# 4         5                                  connected of
# 5         6                   director (rami makhlouf) of
# 6         7                director / beneficial owner of
# 7         8  director / shareholder / beneficial owner of
# 8         9                     director / shareholder of
# 9        10                   director and shareholder of
# 10       11                                   director of
# 11       12                          first beneficiary of
# 12       13                      grantee of a mortgage of
# 13       14                       member / shareholder of
# 14       15               member of foundation council of
# ...

# %%
roles_df.insert(0, 'role_id', range(1, 1 + len(roles_df)))

# %%
roles_df = roles_df[["role_id","role_type"]]

# %%
roles_df.to_sql('roles_2307_2325', engine, if_exists='append', index=False)
# Out:
# 31

# %% [markdown]
# ## Officers

# %%
max_lengths = {}

# Iterate over each column in the DataFrame

for column in officer.columns: # Calculate the maximum length for each cell in the column
    max_length_in_column = officer[column].astype(str).apply(len).max()

    # Store the result in the dictionary
    max_lengths[column] = max_length_in_column

# Print the maximum lengths for each column

for column, max_length in max_lengths.items():
    print(f"Maximum length in '{column}': {max_length}")
# Out:
# Maximum length in 'node_id': 8
# Maximum length in 'name': 200
# Maximum length in 'country_codes': 3
# Maximum length in 'countries': 32
# Maximum length in 'sourceID': 13
# Maximum length in 'valid_until': 46
# Maximum length in 'note': 865

# %%
officer.head()
# Out:
#     node_id                  name country_codes    countries       sourceID  \
# 0  12000001            KIM SOO IN           KOR  South Korea  Panama Papers
# 1  12000002             Tian Yuan           CHN        China  Panama Papers
# 2  12000003  GREGORY JOHN SOLOMON           AUS    Australia  Panama Papers
# 3  12000004        MATSUDA MASUMI           JPN        Japan  Panama Papers
# 4  12000005           HO THUY NGA           VNM     Viet Nam  Panama Papers
#
#                                       valid_until note
# 0  The Panama Papers data is current through 2015  NaN
# 1  The Panama Papers data is current through 2015  NaN
# 2  The Panama Papers data is current through 2015  NaN
# 3  The Panama Papers data is current through 2015  NaN
# 4  The Panama Papers data is current through 2015  NaN

# %%
officer["name"] = officer["name"].fillna(value="no_name")

# %%
db_officer_columns = [
    'officer_id',
    'name',
    'country_code',
    'country_name',
    'source_id',
    'valid_until',
    'note'
]

# %%
column_mapping = dict(zip(officer.columns, db_table_columns))
officer.rename(columns=column_mapping, inplace=True)

# %%
data_parser(officer, db_officer_columns, "officers_2307_2325")
# Out:
# Data successfully parsed to officers_2307_2325 table

# %%
officer.head()
# Out:
#    officer_id                  name country_code country_name      source_id  \
# 0    12000001            KIM SOO IN          KOR  South Korea  Panama Papers
# 1    12000002             Tian Yuan          CHN        China  Panama Papers
# 2    12000003  GREGORY JOHN SOLOMON          AUS    Australia  Panama Papers
# 3    12000004        MATSUDA MASUMI          JPN        Japan  Panama Papers
# 4    12000005           HO THUY NGA          VNM     Viet Nam  Panama Papers
#
#                                       valid_until note
# 0  The Panama Papers data is current through 2015  NaN
# 1  The Panama Papers data is current through 2015  NaN
# 2  The Panama Papers data is current through 2015  NaN
# 3  The Panama Papers data is current through 2015  NaN
# 4  The Panama Papers data is current through 2015  NaN

# %%
officer.to_sql('officers_2325', engine, if_exists='append', index=False)
# Out:
# 402

# %% [markdown]
# ## Role_Officers

# %%
edges[edges["TYPE"] == "officer_of"]["link"].value_counts()
# Out:
# link
# shareholder of                                  293961
# beneficiary of                                   15150
# beneficial owner of                                 79
# director of                                         48
# power of attorney of                                29
# owner, director and shareholder of                  28
# owner of                                            16
# director / shareholder of                            6
# beneficiary, shareholder and director of             6
# sole shareholder of                                  4
# director / beneficial owner of                       4
# member of foundation council of                      3
# secretary of                                         3
# principal beneficiary of                             3
# connected of                                         3
# sole signatory of                                    2
# director / shareholder / beneficial owner of         2
# ...

# %%
tmp = edges[edges["TYPE"] == "officer_of"].copy()

# %%
tmp[tmp['START_ID'].astype(str).str.startswith('10')].shape[0]
# Out:
# 0

# %%
officers_roles_entities = edges.loc[edges['TYPE'] == 'officer_of'].copy()
officers_roles_entities.head()
# Out:
#         START_ID        TYPE    END_ID            link   start_date  \
# 218944  12000001  officer_of  10073324  shareholder of  19-NOV-1999
# 218946  12000002  officer_of  10148386  shareholder of  30-MAR-2012
# 218948  12000003  officer_of  10024966  shareholder of  14-JAN-2010
# 218950  12000004  officer_of  10004763  shareholder of  23-JUL-2012
# 218952  12000005  officer_of  10206741  shareholder of  13-SEP-2010
#
#            end_date       sourceID  \
# 218944  04-JUL-2000  Panama Papers
# 218946  06-JUL-2012  Panama Papers
# 218948          NaN  Panama Papers
# 218950          NaN  Panama Papers
# 218952          NaN  Panama Papers
#
#                                            valid_until
# 218944  The Panama Papers data is current through 2015
# 218946  The Panama Papers data is current through 2015
# 218948  The Panama Papers data is current through 2015
# 218950  The Panama Papers data is current through 2015
# 218952  The Panama Papers data is current through 2015

# %%
tmp.head()
# Out:
#         START_ID        TYPE    END_ID            link   start_date  \
# 218944  12000001  officer_of  10073324  shareholder of  19-NOV-1999
# 218946  12000002  officer_of  10148386  shareholder of  30-MAR-2012
# 218948  12000003  officer_of  10024966  shareholder of  14-JAN-2010
# 218950  12000004  officer_of  10004763  shareholder of  23-JUL-2012
# 218952  12000005  officer_of  10206741  shareholder of  13-SEP-2010
#
#            end_date       sourceID  \
# 218944  04-JUL-2000  Panama Papers
# 218946  06-JUL-2012  Panama Papers
# 218948          NaN  Panama Papers
# 218950          NaN  Panama Papers
# 218952          NaN  Panama Papers
#
#                                            valid_until
# 218944  The Panama Papers data is current through 2015
# 218946  The Panama Papers data is current through 2015
# 218948  The Panama Papers data is current through 2015
# 218950  The Panama Papers data is current through 2015
# 218952  The Panama Papers data is current through 2015

# %%
print(roles_officers["START_ID"].head())

print(roles_officers["END_ID"].head())
# Out:
# 218944    12000001
# 218946    12000002
# 218948    12000003
# 218950    12000004
# 218952    12000005
# Name: START_ID, dtype: int64
# 218944    10073324
# 218946    10148386
# 218948    10024966
# 218950    10004763
# 218952    10206741
# Name: END_ID, dtype: int64

# %%
roles_df
# Out:
#     role_id                                     role_type
# 0         1                       authorized signatory of
# 1         2                           beneficial owner of
# 2         3                                beneficiary of
# 3         4      beneficiary, shareholder and director of
# 4         5                                  connected of
# 5         6                   director (rami makhlouf) of
# 6         7                director / beneficial owner of
# 7         8  director / shareholder / beneficial owner of
# 8         9                     director / shareholder of
# 9        10                   director and shareholder of
# 10       11                                   director of
# 11       12                          first beneficiary of
# 12       13                      grantee of a mortgage of
# 13       14                       member / shareholder of
# 14       15               member of foundation council of
# ...

# %%
tmp = tmp.merge(roles_df, left_on='link', right_on='role_type').copy()
tmp.head()
# Out:
#    START_ID        TYPE    END_ID            link   start_date     end_date  \
# 0  12000001  officer_of  10073324  shareholder of  19-NOV-1999  04-JUL-2000
# 1  12000002  officer_of  10148386  shareholder of  30-MAR-2012  06-JUL-2012
# 2  12000003  officer_of  10024966  shareholder of  14-JAN-2010          NaN
# 3  12000004  officer_of  10004763  shareholder of  23-JUL-2012          NaN
# 4  12000005  officer_of  10206741  shareholder of  13-SEP-2010          NaN
#
#         sourceID                                     valid_until  role_id  \
# 0  Panama Papers  The Panama Papers data is current through 2015       27
# 1  Panama Papers  The Panama Papers data is current through 2015       27
# 2  Panama Papers  The Panama Papers data is current through 2015       27
# 3  Panama Papers  The Panama Papers data is current through 2015       27
# 4  Panama Papers  The Panama Papers data is current through 2015       27
#
#         role_type
# 0  shareholder of
# 1  shareholder of
# ...

# %%
tmp["role_id"].value_counts()
# Out:
# role_id
# 27    293961
# 3      15150
# 2         79
# 11        48
# 19        29
# 17        28
# 16        16
# 9          6
# 4          6
# 29         4
# 7          4
# 15         3
# 25         3
# 23         3
# 5          3
# 31         2
# 8          2
# 6          2
# 28         2
# 24         1
# 12         1
# 30         1
# 10         1
# 13         1
# 1          1
# 22         1
# 18         1
# 21         1
# 20         1
# 14         1
# 26         1
# Name: count, dtype: int64

# %%
tmp[tmp['END_ID'].astype(str).str.startswith('10')].shape[0]
# Out:
# 309357

# %%
tmp[~tmp['END_ID'].astype(str).str.startswith('10')].shape[0]
# Out:
# 6

# %%
officers_roles_entities = tmp[tmp['END_ID'].astype(str).str.startswith('10')].copy()
officers_roles_entities.head()
# Out:
#    START_ID  role_id    END_ID   start_date     end_date       sourceID  \
# 0  12000001       27  10073324  19-NOV-1999  04-JUL-2000  Panama Papers
# 1  12000002       27  10148386  30-MAR-2012  06-JUL-2012  Panama Papers
# 2  12000003       27  10024966  14-JAN-2010          NaN  Panama Papers
# 3  12000004       27  10004763  23-JUL-2012          NaN  Panama Papers
# 4  12000005       27  10206741  13-SEP-2010          NaN  Panama Papers
#
#                                       valid_until
# 0  The Panama Papers data is current through 2015
# 1  The Panama Papers data is current through 2015
# 2  The Panama Papers data is current through 2015
# 3  The Panama Papers data is current through 2015
# 4  The Panama Papers data is current through 2015

# %%
officers_roles_officers = tmp[tmp['END_ID'].astype(str).str.startswith('12')].copy()
officers_roles_officers
# Out:
#         START_ID  role_id    END_ID start_date end_date       sourceID  \
# 294009  15004501       11  12049524        NaN      NaN  Panama Papers
# 294010  15004501       11  12105739        NaN      NaN  Panama Papers
# 294011  15004501       11  12171785        NaN      NaN  Panama Papers
# 294012  15004501       11  12171786        NaN      NaN  Panama Papers
# 294013  15004501       11  12105740        NaN      NaN  Panama Papers
#
#                                            valid_until
# 294009  The Panama Papers data is current through 2015
# 294010  The Panama Papers data is current through 2015
# 294011  The Panama Papers data is current through 2015
# 294012  The Panama Papers data is current through 2015
# 294013  The Panama Papers data is current through 2015

# %%
officers_roles_intermediaries = tmp[tmp['END_ID'].astype(str).str.startswith('11')].copy()
officers_roles_intermediaries
# Out:
#         START_ID  role_id    END_ID start_date end_date       sourceID  \
# 309344  15003301       13  11005367        NaN      NaN  Panama Papers
#
#                                            valid_until
# 309344  The Panama Papers data is current through 2015

# %%
#officers_roles_entities
#officers_roles_officers
#officers_roles_intermediaries

# %%
tmp.drop(columns=["TYPE","link","role_type"], inplace=True)
tmp.head()
# Out:
#    START_ID    END_ID   start_date     end_date       sourceID  \
# 0  12000001  10073324  19-NOV-1999  04-JUL-2000  Panama Papers
# 1  12000002  10148386  30-MAR-2012  06-JUL-2012  Panama Papers
# 2  12000003  10024966  14-JAN-2010          NaN  Panama Papers
# 3  12000004  10004763  23-JUL-2012          NaN  Panama Papers
# 4  12000005  10206741  13-SEP-2010          NaN  Panama Papers
#
#                                       valid_until  role_id
# 0  The Panama Papers data is current through 2015       27
# 1  The Panama Papers data is current through 2015       27
# 2  The Panama Papers data is current through 2015       27
# 3  The Panama Papers data is current through 2015       27
# 4  The Panama Papers data is current through 2015       27

# %%
#make the roles_id column the second column in roles_officers_2 using df[column1, column2, column3]= df[column2, column1, column3]
tmp = tmp[['START_ID', 'role_id', 'END_ID', 'start_date', 'end_date', 'sourceID', 'valid_until']]
tmp.head()
# Out:
#    START_ID  role_id    END_ID   start_date     end_date       sourceID  \
# 0  12000001       27  10073324  19-NOV-1999  04-JUL-2000  Panama Papers
# 1  12000002       27  10148386  30-MAR-2012  06-JUL-2012  Panama Papers
# 2  12000003       27  10024966  14-JAN-2010          NaN  Panama Papers
# 3  12000004       27  10004763  23-JUL-2012          NaN  Panama Papers
# 4  12000005       27  10206741  13-SEP-2010          NaN  Panama Papers
#
#                                       valid_until
# 0  The Panama Papers data is current through 2015
# 1  The Panama Papers data is current through 2015
# 2  The Panama Papers data is current through 2015
# 3  The Panama Papers data is current through 2015
# 4  The Panama Papers data is current through 2015

# %%
officers_roles_entities.insert(0, 'officer_role_entity_id', range(1, 1 + len(officers_roles_entities)))

# %%
officers_roles_entities.head()
# Out:
#    officer_role_entity_id  START_ID  role_id    END_ID   start_date  \
# 0                       1  12000001       27  10073324  19-NOV-1999
# 1                       2  12000002       27  10148386  30-MAR-2012
# 2                       3  12000003       27  10024966  14-JAN-2010
# 3                       4  12000004       27  10004763  23-JUL-2012
# 4                       5  12000005       27  10206741  13-SEP-2010
#
#       end_date       sourceID                                     valid_until
# 0  04-JUL-2000  Panama Papers  The Panama Papers data is current through 2015
# 1  06-JUL-2012  Panama Papers  The Panama Papers data is current through 2015
# 2          NaN  Panama Papers  The Panama Papers data is current through 2015
# 3          NaN  Panama Papers  The Panama Papers data is current through 2015
# 4          NaN  Panama Papers  The Panama Papers data is current through 2015

# %%
db_roe_columns = [
    'officer_role_entity_id',
    'officer_id',
    'role_id',
    'entity_id',
    'start_date',
    'end_date',
    'source_id',
    'valid_until'
]
#column_mapping = dict(zip(roles_officers_2.columns, db_table_columns))

# %%
data_parser(officers_roles_entities, db_roe_columns, "officers_roles_entities_2307_2325")
# Out:
# Data successfully parsed to officer_roles_entities_2307_2325 table

# %%
officers_roles_officers.head()
# Out:
#         START_ID  role_id    END_ID start_date end_date       sourceID  \
# 294009  15004501       11  12049524        NaN      NaN  Panama Papers
# 294010  15004501       11  12105739        NaN      NaN  Panama Papers
# 294011  15004501       11  12171785        NaN      NaN  Panama Papers
# 294012  15004501       11  12171786        NaN      NaN  Panama Papers
# 294013  15004501       11  12105740        NaN      NaN  Panama Papers
#
#                                            valid_until
# 294009  The Panama Papers data is current through 2015
# 294010  The Panama Papers data is current through 2015
# 294011  The Panama Papers data is current through 2015
# 294012  The Panama Papers data is current through 2015
# 294013  The Panama Papers data is current through 2015

# %%
officers_roles_officers = tmp[tmp['END_ID'].astype(str).str.startswith('12')].copy()
officers_roles_officers.insert(0, 'officer_role_officer_id', range(1, 1 + len(officers_roles_officers)))
db_oro_columns = [
    'officer_role_officer_id', 'officer_id_1', 'role_id', 'officer_id_2', 'start_date', 'end_date', 'source_id', 'valid_until'
]
data_parser(officers_roles_officers, db_oro_columns, "officers_roles_officers_2307_2325")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 6
#       2 officers_roles_officers.insert(0, 'officer_role_officer_id', range(1, 1 + len(officers_roles_officers)))
#       3 db_oro_columns = [
#       4     'officer_role_officer_id', 'officer_id_1', 'role_id', 'officer_id_2', 'start_date', 'end_date', 'source_id', 'valid_until'
#       5 ]
# ----> 6 data_parser(officers_roles_officers, db_oro_colunms, "officers_roles_officers_2307_2325")
#
# NameError: name 'db_oro_colunms' is not defined

# %%
data_parser(officers_roles_officers, db_oro_columns, "officers_roles_officers_2307_2325")
# Out:
# Data successfully parsed to officers_roles_officers_2307_2325 table

# %%
officers_roles_intermediaries.head()
# Out:
#         START_ID  role_id    END_ID start_date end_date       sourceID  \
# 309344  15003301       13  11005367        NaN      NaN  Panama Papers
#
#                                            valid_until
# 309344  The Panama Papers data is current through 2015

# %%
officers_roles_intermediaries = tmp[tmp['END_ID'].astype(str).str.startswith('11')].copy()
officers_roles_intermediaries.insert(0, 'officer_role_intermediary_id', range(1, 1 + len(officers_roles_intermediaries)))
db_ori_columns = [
    'officer_role_intermediary_id', 'officer_id', 'role_id', 'intermediary_id', 'start_date', 'end_date', 'source_id', 'valid_until'
]
data_parser(officers_roles_intermediaries , db_ori_columns, "officers_roles_intermediaries_2307_2325")
# Out:
# Data successfully parsed to officers_roles_intermediaries_2307_2325 table

# %%
intermediary.head()
# Out:
#     node_id                        name country_codes      countries  \
# 0  11000001     MICHAEL PAPAGEORGE, MR.           ZAF   South Africa
# 1  11000002          CORFIDUCIA ANSTALT           LIE  Liechtenstein
# 2  11000003               DAVID, RONALD           MCO         Monaco
# 3  11000004  DE  BOUTSELIS, JEAN-PIERRE           BEL        Belgium
# 4  11000005    THE LEVANT LAWYERS (TLL)           LBN        Lebanon
#
#       status       sourceID                                      valid_until  \
# 0     ACTIVE  Panama Papers  The Panama Papers  data is current through 2015
# 1     ACTIVE  Panama Papers  The Panama Papers  data is current through 2015
# 2  SUSPENDED  Panama Papers  The Panama Papers  data is current through 2015
# 3  SUSPENDED  Panama Papers  The Panama Papers  data is current through 2015
# 4     ACTIVE  Panama Papers  The Panama Papers  data is current through 2015
#
#   note
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
intermediary[intermediary["node_id"] == 12049524]
# Out:
# Empty DataFrame
# Columns: [node_id, name, country_codes, countries, status, sourceID, valid_until, note]
# Index: []

# %%
roles_officers[roles_officers["END_ID"] == 11005367]
# Out:
#         START_ID        TYPE    END_ID                      link start_date  \
# 674026  15003301  officer_of  11005367  grantee of a mortgage of        NaN
#
#        end_date       sourceID                                     valid_until
# 674026      NaN  Panama Papers  The Panama Papers data is current through 2015

# %%
entity[entity["entity_id"].astype(str).str.startswith("10")]
# Out:
#         entity_id                                         name jurisdiction  \
# 0        10000001     TIANSHENG INDUSTRY AND TRADING CO., LTD.          SAM
# 1        10000002  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.          SAM
# 2        10000003                           HOTFOCUS CO., LTD.          SAM
# 3        10000004              SKY-BLUE GIFTS & TOYS CO., LTD.          SAM
# 4        10000005         FORTUNEMAKER INVESTMENTS CORPORATION          SAM
# ...           ...                                          ...          ...
# 213629   10214482                MILLION TECH DEVELOPMENT LTD.          BVI
# 213630   10214483          FAITH CONNECTION INTERNATIONAL LTD.          BVI
# 213631   10214484             LARK OVERSEAS INVESTMENT LIMITED          BVI
# 213632   10214486                         ASTRA SKIES  LIMITED          BVI
# 213633   10214487                  Kilimanjaro Capital Limited          BVI
#
# ...

# %%
entity[entity["entity_id"] == 11005367]
# Out:
# Empty DataFrame
# Columns: [entity_id, name, jurisdiction, jurisdiction_description, country_code, country_name, incorporation_date, inactivation_date, struck_off_date, closed_date, ibc_ruc, status, company_type, service_provider, source_id, valid_until, note]
# Index: []

# %%
officer[officer['officer_id']== 11005367]
# Out:
# Empty DataFrame
# Columns: [officer_id, name, country_code, country_name, source_id, valid_until, note]
# Index: []

# %%
officer[officer["name"] == "King Salman bin Abdulaziz bin Abdulrahman Al Saud"]
# Out:
#         officer_id                                               name  \
# 238383    15004501  King Salman bin Abdulaziz bin Abdulrahman Al Saud
#
#        country_code country_name      source_id  \
# 238383          NaN          NaN  Panama Papers
#
#                                            valid_until  \
# 238383  The Panama Papers data is current through 2015
#
#                                                note
# 238383  Record manually added from leaked documents

# %%
edges[edges["START_ID"] == 15004501]
# Out:
#         START_ID        TYPE    END_ID         link start_date end_date  \
# 674065  15004501  officer_of  12049524  director of        NaN      NaN
# 674066  15004501  officer_of  12105739  director of        NaN      NaN
# 674067  15004501  officer_of  12171785  director of        NaN      NaN
# 674068  15004501  officer_of  12171786  director of        NaN      NaN
# 674069  15004501  officer_of  12105740  director of        NaN      NaN
#
#              sourceID                                     valid_until
# 674065  Panama Papers  The Panama Papers data is current through 2015
# 674066  Panama Papers  The Panama Papers data is current through 2015
# 674067  Panama Papers  The Panama Papers data is current through 2015
# 674068  Panama Papers  The Panama Papers data is current through 2015
# 674069  Panama Papers  The Panama Papers data is current through 2015

# %%
entity[entity["entity_id"] == 12049524]
# Out:
# Empty DataFrame
# Columns: [entity_id, name, jurisdiction, jurisdiction_description, country_code, country_name, incorporation_date, inactivation_date, struck_off_date, closed_date, ibc_ruc, status, company_type, service_provider, source_id, valid_until, note]
# Index: []

# %%
officer[officer["officer_id"] == 12049524]
# Out:
#        officer_id                          name country_code country_name  \
# 47009    12049524  SAFASON CORPORATION SPF S.A.          NaN          NaN
#
#            source_id                                     valid_until note
# 47009  Panama Papers  The Panama Papers data is current through 2015  NaN

# %%
officer[officer["name"] == "George Hill Nominees Limited"]
# Out:
#         officer_id                          name country_code country_name  \
# 1448      12003957  George Hill Nominees Limited          AIA     Anguilla
# 11580     12014095  George Hill Nominees Limited          AIA     Anguilla
# 92908     12095414  George Hill Nominees Limited          AIA     Anguilla
# 100983    12103348  George Hill Nominees Limited          AIA     Anguilla
# 101981    12104394  George Hill Nominees Limited          AIA     Anguilla
# 162570    12163606  George Hill Nominees Limited          AIA     Anguilla
# 195020    12197113  George Hill Nominees Limited          AIA     Anguilla
# 219940    12222256  George Hill Nominees Limited          AIA     Anguilla
# 224548    12001992  George Hill Nominees Limited          AIA     Anguilla
#
#             source_id                                     valid_until note
# 1448    Panama Papers  The Panama Papers data is current through 2015  NaN
# ...

# %%
entity[entity['name'].str.contains("safason", case=False)]
# Out:
# Empty DataFrame
# Columns: [entity_id, name, jurisdiction, jurisdiction_description, country_code, country_name, incorporation_date, inactivation_date, struck_off_date, closed_date, ibc_ruc, status, company_type, service_provider, source_id, valid_until, note]
# Index: []

# %%
entity[entity['name'] == "George Hill Nominees Limited"]
# Out:
#        entity_id                          name jurisdiction  \
# 18988   10019176  George Hill Nominees Limited          ANG
#
#       jurisdiction_description country_code country_name incorporation_date  \
# 18988         British Anguilla          CHE  Switzerland        06-MAR-2012
#
#       inactivation_date struck_off_date  closed_date  ibc_ruc  status  \
# 18988               NaN             NaN          NaN  1025352  Active
#
#        company_type service_provider      source_id  \
# 18988           NaN  Mossack Fonseca  Panama Papers
#
#                                           valid_until note
# 18988  The Panama Papers data is current through 2015  NaN

# %% [markdown]
# ## Intermediator

# %%
intermediary.shape
# Out:
# (14110, 8)

# %%
intermediary["node_id"].nunique()
# Out:
# 14110

# %%
max_lengths = {}

# Iterate over each column in the DataFrame
for column in intermediary.columns:
    # Calculate the maximum length for each cell in the column
    max_length_in_column = intermediary[column].astype(str).apply(len).max()
    
    # Store the result in the dictionary
    max_lengths[column] = max_length_in_column

# Print the maximum lengths for each column
for column, max_length in max_lengths.items():
    print(f"Maximum length in '{column}': {max_length}")
# Out:
# Maximum length in 'node_id': 8
# Maximum length in 'name': 82
# Maximum length in 'country_codes': 7
# Maximum length in 'countries': 40
# Maximum length in 'status': 34
# Maximum length in 'sourceID': 13
# Maximum length in 'valid_until': 47
# Maximum length in 'note': 865

# %%
intermediary_2 = intermediary.copy()

# %%
intermediary_2[intermediary_2['intermediary_id'].astype(str).str.startswith('11')].shape[0]
# Out:
# 14110

# %%
db_table_columns = [
'intermediary_id',
'name',
'country_code',
'country_name',
'status',
'source_id',
'valid_until',
'note'
]
column_mapping = dict(zip(intermediary_2.columns, db_table_columns))
intermediary_2.rename(columns=column_mapping, inplace=True)

# %%
intermediary_2.head()
# Out:
#    intermediary_id                        name country_code   country_name  \
# 0         11000001     MICHAEL PAPAGEORGE, MR.          ZAF   South Africa
# 1         11000002          CORFIDUCIA ANSTALT          LIE  Liechtenstein
# 2         11000003               DAVID, RONALD          MCO         Monaco
# 3         11000004  DE  BOUTSELIS, JEAN-PIERRE          BEL        Belgium
# 4         11000005    THE LEVANT LAWYERS (TLL)          LBN        Lebanon
#
#       status      source_id                                      valid_until  \
# 0     ACTIVE  Panama Papers  The Panama Papers  data is current through 2015
# 1     ACTIVE  Panama Papers  The Panama Papers  data is current through 2015
# 2  SUSPENDED  Panama Papers  The Panama Papers  data is current through 2015
# 3  SUSPENDED  Panama Papers  The Panama Papers  data is current through 2015
# 4     ACTIVE  Panama Papers  The Panama Papers  data is current through 2015
#
#   note
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
intermediary_2.to_sql('intermediaries_2325', engine, if_exists='append', index=False)
# Out:
# 110

# %%
db_inter_columns = [
'intermediary_id', 'name', 'country_code', 'country_name', 'status', 'source_id', 'valid_until', 'note'
]

data_parser(intermediary, db_inter_columns, "intermediaries_2307_2325")
# Out:
# Data successfully parsed to intermediaries_2307_2325 table

# %% [markdown]
# ## Intermediaries Entities

# %%
edges.head()
# Out:
#    START_ID                TYPE    END_ID                link start_date  \
# 0  10000035  registered_address  14095990  registered address        NaN
# 1  10000044  registered_address  14091035  registered address        NaN
# 2  10000055  registered_address  14095990  registered address        NaN
# 3  10000064  registered_address  14091429  registered address        NaN
# 4  10000089  registered_address  14098253  registered address        NaN
#
#   end_date       sourceID valid_until
# 0      NaN  Panama Papers         NaN
# 1      NaN  Panama Papers         NaN
# 2      NaN  Panama Papers         NaN
# 3      NaN  Panama Papers         NaN
# 4      NaN  Panama Papers         NaN

# %%
inter_entity = edges[edges["TYPE"] == "intermediary_of"].copy()
inter_entity.head()
# Out:
#       START_ID             TYPE    END_ID             link start_date  \
# 5310  11000001  intermediary_of  10208879  intermediary of        NaN
# 5311  11000001  intermediary_of  10198662  intermediary of        NaN
# 5312  11000001  intermediary_of  10159927  intermediary of        NaN
# 5313  11000001  intermediary_of  10165779  intermediary of        NaN
# 5314  11000001  intermediary_of  10152967  intermediary of        NaN
#
#      end_date       sourceID                                     valid_until
# 5310      NaN  Panama Papers  The Panama Papers data is current through 2015
# 5311      NaN  Panama Papers  The Panama Papers data is current through 2015
# 5312      NaN  Panama Papers  The Panama Papers data is current through 2015
# 5313      NaN  Panama Papers  The Panama Papers data is current through 2015
# 5314      NaN  Panama Papers  The Panama Papers data is current through 2015

# %%
inter_entity.drop(columns=["TYPE","link"], inplace=True)

# %%
inter_entity.head()
# Out:
#       intermediary_entity_id  intermediary_id  entity_id start_date end_date  \
# 5310                       1         11000001   10208879        NaN      NaN
# 5311                       2         11000001   10198662        NaN      NaN
# 5312                       3         11000001   10159927        NaN      NaN
# 5313                       4         11000001   10165779        NaN      NaN
# 5314                       5         11000001   10152967        NaN      NaN
#
#           source_id                                     valid_until
# 5310  Panama Papers  The Panama Papers data is current through 2015
# 5311  Panama Papers  The Panama Papers data is current through 2015
# 5312  Panama Papers  The Panama Papers data is current through 2015
# 5313  Panama Papers  The Panama Papers data is current through 2015
# 5314  Panama Papers  The Panama Papers data is current through 2015

# %%
inter_entity.insert(0, 'intermediary_entity_id', range(1, 1 + len(inter_entity)))

# %%
db_table_columns = [
'intermediary_entity_id',
'intermediary_id',
'entity_id',
'start_date',
'end_date',
'source_id',
'valid_until'
]
column_mapping = dict(zip(inter_entity.columns, db_table_columns))
inter_entity.rename(columns=column_mapping, inplace=True)

# %%
inter_entity.to_sql('interm_entities_2325', engine, if_exists='append', index=False)
# Out:
# 634

# %% [markdown]
# ## Addresses

# %%
address.head()
# Out:
#     node_id  name                                            address  \
# 0  14000001   NaN       -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920
# 1  14000002   NaN            "Almaly Village" v.5, Almaty Kazakhstan
# 2  14000003   NaN  "Cantonia" South Road St Georges Hill Weybridg...
# 3  14000004   NaN  "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...
# 4  14000005   NaN  "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...
#
#   country_codes       countries       sourceID  \
# 0           SGP       Singapore  Panama Papers
# 1           KAZ      Kazakhstan  Panama Papers
# 2           GBR  United Kingdom  Panama Papers
# 3           GGY        Guernsey  Panama Papers
# 4           KEN           Kenya  Panama Papers
#
#                                        valid_until  note
# 0  The Panama Papers  data is current through 2015   NaN
# 1  The Panama Papers  data is current through 2015   NaN
# 2  The Panama Papers  data is current through 2015   NaN
# ...

# %%
max_lengths = {}

# Iterate over each column in the DataFrame
for column in address.columns:
    # Calculate the maximum length for each cell in the column
    max_length_in_column = address[column].astype(str).apply(len).max()
    
    # Store the result in the dictionary
    max_lengths[column] = max_length_in_column

# Print the maximum lengths for each column
for column, max_length in max_lengths.items():
    print(f"Maximum length in '{column}': {max_length}")
# Out:
# Maximum length in 'node_id': 8
# Maximum length in 'name': 3
# Maximum length in 'address': 667
# Maximum length in 'country_codes': 3
# Maximum length in 'countries': 32
# Maximum length in 'sourceID': 13
# Maximum length in 'valid_until': 47
# Maximum length in 'note': 3

# %%
address_2 = address.copy()

# %%
db_table_columns = [
'address_id',   
'name',
'address',
'country_code',
'country_name',
'source_id',
'valid_until',
'note'
]
column_mapping = dict(zip(address_2.columns, db_table_columns))
address_2.rename(columns=column_mapping, inplace=True)

# %%
address_2.head()
# Out:
#    address_id  name                                            address  \
# 0    14000001   NaN       -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920
# 1    14000002   NaN            "Almaly Village" v.5, Almaty Kazakhstan
# 2    14000003   NaN  "Cantonia" South Road St Georges Hill Weybridg...
# 3    14000004   NaN  "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...
# 4    14000005   NaN  "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...
#
#   country_code    country_name      source_id  \
# 0          SGP       Singapore  Panama Papers
# 1          KAZ      Kazakhstan  Panama Papers
# 2          GBR  United Kingdom  Panama Papers
# 3          GGY        Guernsey  Panama Papers
# 4          KEN           Kenya  Panama Papers
#
#                                        valid_until  note
# 0  The Panama Papers  data is current through 2015   NaN
# 1  The Panama Papers  data is current through 2015   NaN
# 2  The Panama Papers  data is current through 2015   NaN
# ...

# %%
address_2.to_sql('addresses_2325', engine, if_exists='append', index=False)
# Out:
# 454

# %% [markdown]
# ## Addresss entities

# %%
edges.head()
# Out:
#    START_ID                TYPE    END_ID                link start_date  \
# 0  10000035  registered_address  14095990  registered address        NaN
# 1  10000044  registered_address  14091035  registered address        NaN
# 2  10000055  registered_address  14095990  registered address        NaN
# 3  10000064  registered_address  14091429  registered address        NaN
# 4  10000089  registered_address  14098253  registered address        NaN
#
#   end_date       sourceID valid_until
# 0      NaN  Panama Papers         NaN
# 1      NaN  Panama Papers         NaN
# 2      NaN  Panama Papers         NaN
# 3      NaN  Panama Papers         NaN
# 4      NaN  Panama Papers         NaN

# %%
edges[edges["TYPE"] == "registered_address"]["link"].value_counts()
# Out:
# link
# registered address    151105
# Name: count, dtype: int64

# %%
edges["TYPE"].value_counts()
# Out:
# TYPE
# officer_of            309363
# intermediary_of       213634
# registered_address    151105
# Name: count, dtype: int64

# %%
register_addresses = edges[edges["TYPE"] == "registered_address"].copy()
register_addresses.head()
# Out:
#    START_ID                TYPE    END_ID                link start_date  \
# 0  10000035  registered_address  14095990  registered address        NaN
# 1  10000044  registered_address  14091035  registered address        NaN
# 2  10000055  registered_address  14095990  registered address        NaN
# 3  10000064  registered_address  14091429  registered address        NaN
# 4  10000089  registered_address  14098253  registered address        NaN
#
#   end_date       sourceID valid_until
# 0      NaN  Panama Papers         NaN
# 1      NaN  Panama Papers         NaN
# 2      NaN  Panama Papers         NaN
# 3      NaN  Panama Papers         NaN
# 4      NaN  Panama Papers         NaN

# %%
#there are not intermediaties that have register addresses
register_addresses[register_addresses['END_ID'].astype(str).str.startswith('10')].shape[0]
# Out:
# 0

# %%
#there are not intermediaties that have register addresses
register_addresses[register_addresses['START_ID'].astype(str).str.startswith('10')].shape[0]
# Out:
# 5310

# %%
register_addresses.drop(columns=["TYPE","link"], inplace=True)
register_addresses
# Out:
#         START_ID    END_ID start_date end_date       sourceID  \
# 0       10000035  14095990        NaN      NaN  Panama Papers
# 1       10000044  14091035        NaN      NaN  Panama Papers
# 2       10000055  14095990        NaN      NaN  Panama Papers
# 3       10000064  14091429        NaN      NaN  Panama Papers
# 4       10000089  14098253        NaN      NaN  Panama Papers
# ...          ...       ...        ...      ...            ...
# 673985  13002956  14038313        NaN      NaN  Panama Papers
# 673987  13002957  14090058        NaN      NaN  Panama Papers
# 673989  13002958  14089239        NaN      NaN  Panama Papers
# 673992  13002960  14026068        NaN      NaN  Panama Papers
# 673994  13002961  14085964        NaN      NaN  Panama Papers
#
#                                            valid_until
# 0                                                  NaN
# 1                                                  NaN
# ...

# %%
addresses_entities = register_addresses[register_addresses['START_ID'].astype(str).str.startswith('10')].copy()
addresses_entities.head()
# Out:
#    officer_entity_address_id  START_ID    END_ID start_date end_date  \
# 0                          1  10000035  14095990        NaN      NaN
# 1                          2  10000044  14091035        NaN      NaN
# 2                          3  10000055  14095990        NaN      NaN
# 3                          4  10000064  14091429        NaN      NaN
# 4                          5  10000089  14098253        NaN      NaN
#
#         sourceID valid_until
# 0  Panama Papers         NaN
# 1  Panama Papers         NaN
# 2  Panama Papers         NaN
# 3  Panama Papers         NaN
# 4  Panama Papers         NaN

# %%
addresses_entities.shape
# Out:
# (5310, 7)

# %%
max_lengths = {}

# Iterate over each column in the DataFrame
for column in register_addresses.columns:
    # Calculate the maximum length for each cell in the column
    max_length_in_column = register_addresses[column].astype(str).apply(len).max()
    
    # Store the result in the dictionary
    max_lengths[column] = max_length_in_column

# Print the maximum lengths for each column
for column, max_length in max_lengths.items():
    print(f"Maximum length in '{column}': {max_length}")
# Out:
# Maximum length in 'START_ID': 8
# Maximum length in 'END_ID': 8
# Maximum length in 'start_date': 3
# Maximum length in 'end_date': 3
# Maximum length in 'sourceID': 13
# Maximum length in 'valid_until': 46

# %%
addresses_entities.insert(0, 'entity_address_id', range(1, 1 + len(addresses_entities)))

# %%
addresses_entities = addresses_entities.rename(columns={"register_address_id": "entity_address_id"})
addresses_entities.head()
# Out:
#    entity_address_id  START_ID    END_ID start_date end_date       sourceID  \
# 0                  1  10000035  14095990        NaN      NaN  Panama Papers
# 1                  2  10000044  14091035        NaN      NaN  Panama Papers
# 2                  3  10000055  14095990        NaN      NaN  Panama Papers
# 3                  4  10000064  14091429        NaN      NaN  Panama Papers
# 4                  5  10000089  14098253        NaN      NaN  Panama Papers
#
#   valid_until
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
db_table_columns = [
'entity_address_id',
'entity_id',
'address_id',
'start_date',
'end_date',
'source_id',
'valid_until'
]
column_mapping = dict(zip(addresses_entities.columns, db_table_columns))
addresses_entities.rename(columns=column_mapping, inplace=True)
addresses_entities.head()
# Out:
#    entity_address_id  entity_id  address_id start_date end_date  \
# 0                  1   10000035    14095990        NaN      NaN
# 1                  2   10000044    14091035        NaN      NaN
# 2                  3   10000055    14095990        NaN      NaN
# 3                  4   10000064    14091429        NaN      NaN
# 4                  5   10000089    14098253        NaN      NaN
#
#        source_id valid_until
# 0  Panama Papers         NaN
# 1  Panama Papers         NaN
# 2  Panama Papers         NaN
# 3  Panama Papers         NaN
# 4  Panama Papers         NaN

# %%
addresses_entities.to_sql('entities_addresses_2325', engine, if_exists='append', index=False)
# Out:
# 310

# %% [markdown]
# ## Officers addresses

# %%
addresses_officers = register_addresses[~register_addresses['START_ID'].astype(str).str.startswith('10')].copy()
addresses_officers.shape
# Out:
# (145795, 7)

# %%
addresses_officers.head()
# Out:
#         officer_entity_address_id  START_ID    END_ID start_date end_date  \
# 218945                       5311  12000001  14000061        NaN      NaN
# 218947                       5312  12000002  14000022        NaN      NaN
# 218949                       5313  12000003  14000032        NaN      NaN
# 218951                       5314  12000004  14000023        NaN      NaN
# 218953                       5315  12000005  14000031        NaN      NaN
#
#              sourceID                                     valid_until
# 218945  Panama Papers  The Panama Papers data is current through 2015
# 218947  Panama Papers  The Panama Papers data is current through 2015
# 218949  Panama Papers  The Panama Papers data is current through 2015
# 218951  Panama Papers  The Panama Papers data is current through 2015
# 218953  Panama Papers  The Panama Papers data is current through 2015

# %%
addresses_officers.drop(columns=["officer_entity_address_id"], inplace=True)

# %%
addresses_officers.insert(0, 'officer_address_id', range(1, 1 + len(addresses_officers)))

# %%
addresses_officers.head()
# Out:
#         officer_address_id  START_ID    END_ID start_date end_date  \
# 218945                   1  12000001  14000061        NaN      NaN
# 218947                   2  12000002  14000022        NaN      NaN
# 218949                   3  12000003  14000032        NaN      NaN
# 218951                   4  12000004  14000023        NaN      NaN
# 218953                   5  12000005  14000031        NaN      NaN
#
#              sourceID                                     valid_until
# 218945  Panama Papers  The Panama Papers data is current through 2015
# 218947  Panama Papers  The Panama Papers data is current through 2015
# 218949  Panama Papers  The Panama Papers data is current through 2015
# 218951  Panama Papers  The Panama Papers data is current through 2015
# 218953  Panama Papers  The Panama Papers data is current through 2015

# %%
db_table_columns = [
'officer_address_id',
'officer_id',
'address_id',
'start_date',
'end_date',
'source_id',
'valid_until'
]
column_mapping = dict(zip(addresses_officers.columns, db_table_columns))
addresses_officers.rename(columns=column_mapping, inplace=True)
addresses_officers.head()
# Out:
#         officer_address_id  officer_id  address_id start_date end_date  \
# 218945                   1    12000001    14000061        NaN      NaN
# 218947                   2    12000002    14000022        NaN      NaN
# 218949                   3    12000003    14000032        NaN      NaN
# 218951                   4    12000004    14000023        NaN      NaN
# 218953                   5    12000005    14000031        NaN      NaN
#
#             source_id                                     valid_until
# 218945  Panama Papers  The Panama Papers data is current through 2015
# 218947  Panama Papers  The Panama Papers data is current through 2015
# 218949  Panama Papers  The Panama Papers data is current through 2015
# 218951  Panama Papers  The Panama Papers data is current through 2015
# 218953  Panama Papers  The Panama Papers data is current through 2015

# %%
addresses_officers.to_sql('officers_addresses_2325', engine, if_exists='append', index=False)
# Out:
# 795
